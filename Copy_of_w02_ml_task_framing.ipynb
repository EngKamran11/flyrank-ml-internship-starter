# %% [markdown]
# <a href="https://colab.research.google.com/github/EngKamran11/flyrank-ml-internship-starter/blob/main/Copy_of_w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*
# ## My Lane as an ML Task
#
# My chosen lane is **Refresh / Content Opportunity Scoring**.
#
# This is a **classification** machine learning problem because the model predicts whether a page should be considered a high-priority review candidate based on its search performance and content signals.
#
# The goal is to identify pages that are likely to need refreshing so that reviewers can focus on the most important pages first.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*
# ## Target or Proxy
#
# The target is to identify whether a content page is a high-priority review candidate.
#
# For the starter dataset, I will use the existing trend information as a proxy. Pages with a **"down"** trend are treated as needing review, while pages with other trends are considered lower priority.
#
# This target helps rank pages that are more likely to require content updates or improvements.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*
# ## Success Metric
#
# The main success metric is **Precision@50** because the goal is to rank the pages that should be reviewed first.
#
# Precision@50 measures how many of the top 50 recommended pages are actually good review candidates. This metric is useful because content teams usually have limited time and can only review a small number of pages at once.
#
# I will also consider ROC AUC and Average Precision to evaluate the overall performance of the model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*
# ## The Unit of Analysis
#
# The unit of analysis is **one content page** (one row in the dataset).
#
# Each row contains information about a single content page, including its impressions, clicks, sessions, CTR, average position, content age, and trend direction. The model uses these features to decide whether the page should be recommended for review.

# %%
# %cd /content/flyrank-ml-internship-starter
# Out:
# /content/flyrank-ml-internship-starter

# %%
# !git clone https://github.com/EngKamran11/flyrank-ml-internship-starter.git
# %cd flyrank-ml-internship-starter
# !pwd
# Out:
# Cloning into 'flyrank-ml-internship-starter'...
# remote: Enumerating objects: 218, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 218 (delta 62), reused 34 (delta 34), pack-reused 137 (from 1)
# Receiving objects: 100% (218/218), 1.87 MiB | 9.81 MiB/s, done.
# Resolving deltas: 100% (104/104), done.
# /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter

# %%
# %cd /content/flyrank-ml-internship-starter
# !pwd
# Out:
# /content/flyrank-ml-internship-starter
# /content/flyrank-ml-internship-starter

# %%
# !ls
# Out:
# AGENTS.md					LICENSE
# CLAUDE.md					notebooks
# Copy_of_01_first_look_and_discovery.ipynb	outputs
# Copy_of_02_your_first_readable_model.ipynb	README.md
# Copy_of_03_working_with_the_full_release.ipynb	requirements.txt
# Copy_of_w01_research_question.ipynb		scripts
# data						SETUP.md
# DATA_USE.md					skills
# docs						submission
# flyrank-ml-internship-starter			work
# GUIDE.md

# %%
import os
os.getcwd()
# Out:
# '/content/flyrank-ml-internship-starter'

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

# Load the starter dataset
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Show one row to demonstrate the unit of analysis
print("One row represents one content page:")
display(df.head(1))

print("\nDataset Shape:", df.shape)
# Out:
# One row represents one content page:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# 0     20457.0  ...     15000-25000  0.76          10.6             5.88
#
#    scroll_rate  ai_traffic_pct  impression_tier  position_tier  \
# 0         4.55             0.0             good       striking
#
#    trend_direction  trend_pct
# 0             down      -41.4
#
# [1 rows x 44 columns]
# Dataset Shape: (30000, 44)

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*
# ## Features and Exclusions
#
# ### Features
# The model will use observable search and content signals such as:
# - Impressions
# - Clicks
# - Sessions
# - CTR
# - Average Position
# - Content Age
# - Word Count
# - Engagement Rate
# - Scroll Rate
# - AI Traffic Percentage
#
# ### Excluded Fields
# I will not use client names, URLs, or any private information. I will also avoid using fields that could leak the answer or represent future information when building the model.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
# ## Why Machine Learning Helps
#
# Machine learning can analyze many content pages at once and identify patterns that are difficult to detect manually. Instead of reviewing every page individually, the model ranks pages according to their likelihood of needing a content refresh.
#
# This helps content teams save time and focus on the pages that are most likely to benefit from review. The final recommendations support human decision-making rather than replacing it.
